# %% [markdown]
#              P Y T H O N    O O P s     A S S I G N M E N T
# ##THEORY QUESTIONS
#
# ---
#
#
#
# ---
# <br>
#
# ### **Q1. What is Object-Oriented Programming (OOP)?**
#
# - Object-Oriented Programming is a way of designing programs using objects. These objects represent real-world things and contain both data and actions. OOP helps in organizing code and making it easier to maintain and reuse.
#
#  **Example:** A car can be treated as an object with data like speed and color, and actions like drive and stop.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q2. What is a class in OOP?**
#
# - A class is a blueprint used to create objects. It defines the structure and behavior that the objects will have. In simple words, it’s like a design plan that tells how the object should look and act.
#
#  **Example:** A class named `Car` can have properties like brand and model, and actions like start and stop.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q3. What is an object in OOP?**
#
# - An object is a real-world instance of a class. It holds actual values and can perform actions defined in the class. Each object created from the same class can have different values.
#
#  **Example:** If `Car` is a class, then `myCar = Car()` creates an object of that class.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q4. What is the difference between abstraction and encapsulation?**
#
# - Abstraction means hiding the complex details and showing only the important part. Encapsulation means keeping data safe inside an object and not allowing direct access to it.
#
#  **Example:** When we use a mobile phone, we see only the screen (abstraction) but do not see how the internal parts work (encapsulation).
#
# <br>
#
# ---
#
# <br>
#
#
# ### **Q5. What are dunder methods in Python?**
#
# - Dunder methods (short for double underscore) are special methods in Python that start and end with two underscores. They are used for built-in operations.
#
#  **Example:** `__init__` is a dunder method used to initialize a new object.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q6. Explain the concept of inheritance in OOP.**
#
# - Inheritance allows a class to get properties and methods from another class. It helps in reusing code and reducing repetition.
#
#  **Example:** A `Dog` class can inherit from an `Animal` class and get the `speak()` method without rewriting it.
#
# <br>
#
# ---
#
# <br>
#
#
# ### **Q7. What is polymorphism in OOP?**
#
# - Polymorphism means using the same function or method name to do different things based on the object calling it.
#
#  **Example:** A `Bird` class can have a `fly()` method, and both `Sparrow` and `Penguin` can define their own way of flying using the same method name.
#
# <br>
#
# ---
#
# <br>
#
#
# ### **Q8. How is encapsulation achieved in Python?**
#
# - Encapsulation is achieved by making class variables private using an underscore or double underscore. This prevents direct access to data from outside the class.
#
#  **Example:** A bank account class may hide the balance using `__balance` to keep it safe.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q9. What is a constructor in Python?**
#
# - A constructor is a special method called automatically when an object is created. In Python, it is written as `__init__`.
#
#  **Example:** When we create a `Student` object, the constructor can set the student’s name automatically.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q10. What are class and static methods in Python?**
#
# - Class methods are related to the class and can access class variables using `cls`. Static methods do not need class or instance references and are used for general purposes.
#
#  **Example:** A class method can count how many objects are created, while a static method can simply perform calculations.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q11. What is method overloading in Python?**
#
# - Python doesn’t support method overloading directly, but similar results can be achieved using default arguments or special handling inside a method.
#
#  **Example:** A `show()` method can behave differently based on whether arguments are given or not.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q12. What is method overriding in OOP?**
#
# - Method overriding means a child class can provide its own version of a method that already exists in the parent class.
#
#  **Example:** If `Animal` has a `speak()` method and `Dog` changes it to say "Bark", this is overriding.
#
# <br>
#
# ---
#
# <br>
#
#
# ### **Q13. What is a property decorator in Python?**
#
# - A property decorator allows a method to be accessed like an attribute. It is used to get or calculate values safely.
#
#  **Example:** The `@property` decorator can return the area of a circle when we access `circle.area` directly.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q14. Why is polymorphism important in OOP?**
#
# - Polymorphism makes code flexible and reusable. It allows different objects to use the same method name in their own way, which simplifies code and avoids duplication.
#
#  **Example:** Both `Guitar` and `Piano` can use a method `play()`, but perform differently.
#
# <br>
#
# ---
#
# <br>
#
#
#
# ### **Q15. What is an abstract class in Python?**
#
# - An abstract class is a base class that cannot be used directly and contains at least one method without a body. Child classes must define the missing methods.
#
#  **Example:** A `Shape` abstract class may have an `area()` method that must be implemented by `Circle` and `Rectangle`.
#
# <br>
#
# ---
#
# <br>
#
#
# ### **Q16. What are the advantages of OOP?**
#
# - OOP makes the code organized, reusable, secure, and easier to manage. It allows dividing the program into small, logical parts (classes) that can be handled easily.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q17. What is the difference between a class variable and an instance variable?**
#
# - A class variable is shared by all objects of the class, while an instance variable is unique to each object.
#
#  **Example:** All students may have the same school name (class variable), but each has a different name (instance variable).
#
# <br>
#
# ---
#
# <br>
#
# ### **Q18. What is multiple inheritance in Python?**
#
# - Multiple inheritance means a class can inherit from more than one parent class. This allows a class to use features from multiple sources.
#
#  **Example:** A `SmartPhone` class can inherit from both `Camera` and `Phone` classes.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q19. Explain the purpose of `__str__` and `__repr__` methods in Python.**
#
# - `__str__` returns a readable string when we print an object, while `__repr__` is meant for developers and shows the object’s technical details.
#
#  **Example:** `__str__` might return “2/3” for a fraction, and `__repr__` might return “Fraction(2,3)”.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q20. What is the significance of the `super()` function in Python?**
#
# - The `super()` function is used in a child class to call a method from the parent class. It helps reuse code and avoid repeating logic.
#
#  **Example:** If the parent class has an `__init__` method, `super().__init__()` can be used to run it inside the child class.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q21. What is the significance of the `__del__` method in Python?**
#
# - The `__del__` method is called when an object is deleted. It can be used to clean up resources or print a message.
#
#  **Example:** When a file object is deleted, `__del__` can close the file automatically.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q22. What is the difference between @staticmethod and @classmethod in Python?**
#
# - A static method does not take any object or class reference and is used for simple functions. A class method takes `cls` and can change class-level data.
#
#  **Example:** A class method can keep track of how many objects are created; a static method can perform math.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q23. How does polymorphism work in Python with inheritance?**
#
# - In inheritance, polymorphism allows child classes to use the same method names as the parent class but with different behavior. This is useful when dealing with many child classes under one base class.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q24. What is method chaining in Python OOP?**
#
# - Method chaining means calling multiple methods on the same object in one line. It works by returning `self` from each method.
#
#  **Example:** `obj.set_name().set_age().show()` calls all methods one after another.
#
# <br>
#
# ---
#
# <br>
#
# ### **Q25. What is the purpose of the `__call__` method in Python?**
#
# - The `__call__` method lets an object act like a function. When we “call” the object using parentheses, Python runs `__call__`.
#
#  **Example:** If a class has `__call__` defined, then writing `obj()` will run that method.
#
# <br>
#
# ---

# %%
# PRACTICAL QUESTIONS



### Q1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method.


class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

d = Dog()
d.speak()




### Q2. Create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.


from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

c = Circle(3)
r = Rectangle(4, 5)
print(c.area())
print(r.area())



### Q3. Multi-level inheritance: Vehicle → Car → ElectricCar


class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

e = ElectricCar("Vehicle", "Tesla", "100kWh")
print(e.type, e.brand, e.battery)



### Q4. Demonstrate polymorphism using Bird, Sparrow, and Penguin.


class Bird:
    def fly(self):
        print("Bird is flying")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high")

class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly")

for b in [Sparrow(), Penguin()]:
    b.fly()




### Q5. Demonstrate encapsulation with a BankAccount class.


class BankAccount:
    def __init__(self):
        self.__balance = 0  # private variable

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Not enough balance")

    def check_balance(self):
        return self.__balance

acc = BankAccount()
acc.deposit(1000)
acc.withdraw(300)
print(acc.check_balance())




### Q6. Runtime polymorphism: Instrument, Guitar, Piano.


class Instrument:
    def play(self):
        print("Instrument is playing")

class Guitar(Instrument):
    def play(self):
        print("Guitar is strumming")

class Piano(Instrument):
    def play(self):
        print("Piano is playing")

for i in [Guitar(), Piano()]:
    i.play()




### Q7. MathOperations class with class and static methods.


class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print(MathOperations.add_numbers(5, 3))
print(MathOperations.subtract_numbers(10, 4))




### Q8. Person class to count total persons created.


class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

p1 = Person("Ram")
p2 = Person("Shyam")
print(Person.total_persons())




### Q9. Fraction class with `__str__` method.


class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

f = Fraction(2, 3)
print(f)




### Q10. Operator overloading with Vector class.


class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(1, 4)
v3 = v1 + v2
print(v3)




### Q11. Person class with greet() method.


class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p = Person("Ravi", 22)
p.greet()




### Q12. Student class with average\_grade() method.


class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

s = Student("Anu", [85, 90, 88])
print(s.average_grade())



### Q13. Rectangle class with set\_dimensions() and area().


class Rectangle:
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

r = Rectangle()
r.set_dimensions(4, 5)
print(r.area())




### Q14. Employee and Manager with calculate\_salary().


class Employee:
    def __init__(self, hours, rate):
        self.hours = hours
        self.rate = rate

    def calculate_salary(self):
        return self.hours * self.rate

class Manager(Employee):
    def __init__(self, hours, rate, bonus):
        super().__init__(hours, rate)
        self.bonus = bonus

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus

m = Manager(40, 50, 1000)
print(m.calculate_salary())




### Q15. Product class with total\_price().

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

p = Product("Pen", 10, 5)
print(p.total_price())




### Q16. Animal class with abstract method sound(). Cow and Sheep implement it.


from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")

Cow().sound()
Sheep().sound()




### Q17. Book class with get\_book\_info().


class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = year

    def get_book_info(self):
        return f"{self.title} by {self.author}, published in {self.year}"

b = Book("Python 101", "John Doe", 2021)
print(b.get_book_info())




### Q18. House and Mansion with added attribute number\_of\_rooms.


class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, rooms):
        super().__init__(address, price)
        self.rooms = rooms

m = Mansion("123 Street", 5000000, 10)
print(m.address, m.price, m.rooms)
# Out:
# Bark!
# 28.259999999999998
# 20
# Vehicle Tesla 100kWh
# Sparrow flies high
# Penguins cannot fly
# 700
# Guitar is strumming
# Piano is playing
# 8
# 6
# 2
# 2/3
# (3, 7)
# Hello, my name is Ravi and I am 22 years old.
# 87.66666666666667
# 20
# 3000
# 50
# Moo
# Baa
# Python 101 by John Doe, published in 2021
# 123 Street 5000000 10
